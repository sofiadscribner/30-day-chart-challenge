# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px

# Data
df = pd.read_csv('byu_degrees.csv')

df
# Out:
#                                            Category  Percent
# 0                                      Agriculture      1.21
# 1                                      Architecture     0.13
# 2                 Area, ethnic, and gender studies      0.75
# 3                          Communication/journalism     5.75
# 4                       Communication technologies      0.32
# 5                 Computer and information sciences     7.02
# 6                                         Education     5.92
# 7                                       Engineering     7.86
# 8   Foreign languages, literatures, and linguistics     4.01
# 9                      Family and consumer sciences     4.12
# 10                                          English     1.45
# 11                     Liberal arts/general studies     0.43
# 12                         Biological/life sciences    12.48
# 13                       Mathematics and statistics     3.36
# ...
